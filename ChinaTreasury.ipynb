# %% [markdown]
# <a href="https://colab.research.google.com/github/jerryYZT/ChinaFundingCondition/blob/main/ChinaTreasury.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install akshare --upgrade
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 96.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 88.1 MB/s eta 0:00:00
# ...
#   Created wheel for jsonpath: filename=jsonpath-0.82.2-py3-none-any.whl size=5615 sha256=a72f0f62159f1e5d3d7563386888c7437a0c987d624737b97f73cfae5e35380d
#   Stored in directory: /root/.cache/pip/wheels/e7/05/b4/89d577f57a132db1638cc928cf085fc0a71ed6ec19cd874d2d
# Successfully built jsonpath
# ...

# %%
import akshare as ak
import pandas as pd

# 1. 看 bond_type 可选值
query = ak.bond_info_cm_query()
print("=== bond_info_cm_query() ===")
display(query)

# 2. 尝试查询国债
treasury = ak.bond_info_cm(
    bond_name="",
    bond_code="",
    bond_issue="",
    bond_type="国债",
    coupon_type="",
    issue_year="",
    underwriter="",
    grade=""
)

print("\n=== treasury shape ===")
print(treasury.shape)

print("\n=== treasury columns ===")
print(treasury.columns.tolist())

print("\n=== treasury sample ===")
display(treasury.head(10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_7385/2252906216.py in <cell line: 0>()
#       3
#       4 # 1. 看 bond_type 可选值
# ----> 5 query = ak.bond_info_cm_query()
#       6 print("=== bond_info_cm_query() ===")
#       7 display(query)
#
# /usr/local/lib/python3.13/dist-packages/akshare/bond/bond_info_cm.py in bond_info_cm_query(symbol)
#      53         r = requests.post(url, headers=headers)
#      54         data_json = r.json()
# ---> 55         temp_df = pd.DataFrame(data_json["data"][f"{symbol_map[symbol]}"])
#      56         if temp_df.shape[1] == 1:
#      57             temp_df.columns = ["name"]
#
# KeyError: 'bondRtngShrt'
